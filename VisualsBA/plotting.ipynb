# %%
from plotting import extract_and_plot_tensorboard_logs

# %%
extract_and_plot_tensorboard_logs(directory='../train/hyperparameters/logs/ppo/batch_size/steps=100000', key_to_log='rollout/ep_rew_mean', average=False)
# Out:
# <div>                            <div id="8b890048-9d29-442d-ba94-3d1738dfb3cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b890048-9d29-442d-ba94-3d1738dfb3cc")) {                    Plotly.newPlot(                        "8b890048-9d29-442d-ba94-3d1738dfb3cc",                        [{"mode":"lines","name":"batch_size=128_1","x":[2048,4096,6144,8192,10240,12288,14336,16384,18432,20480,22528,24576,26624,28672,30720,32768,34816,36864,38912,40960,43008,45056,47104,49152,51200,53248,55296,57344,59392,61440,63488,65536,67584,69632,71680,73728,75776,77824,79872,81920,83968,86016,88064,90112,92160,94208,96256,98304,100352],"y":[218.5910186767578,197.94451904296875,229.96141052246094,255.4666290283203,254.3740997314453,265.0780944824219,272.478363037
# ...
